# %% [markdown]
# # Supplementary generation-stability test
#
# This notebook reproduces the 54-response stability analysis and the separate five-status contact audit. The test assesses between-generation consistency only; it does not repair the failed validation of H1/H2.

# %%
from run_stability_analysis import main
main()

# %% [markdown]
# ## Interpretation
#
# Surface localisation and crisis-contact inclusion were identical across all three repeats in all 18 cells. Actionability was identical in 9/18 cells (64.8% pairwise agreement). Replacement endpoints, unequal completion ceilings, and temperature 0.0 limit inference.
